# %%
import pandas as pd

d={ 'BuffTail': [10, 1, 37, 5, 12],
    'Garden bee': [8, 3 ,19 ,6, 4],
    'Red tail': [18, 9, 1, 2, 4],
    'Honeybee': [12, 13, 16, 9 ,10],
    'Carder bee': [8, 27, 6 ,32, 23]
    }
df=pd.DataFrame(data=d,index=['Thistle','Vipers Bugloss','Golden Rain','Yellow Alfalfa','Blackberry'])
df
# Out:
#                 BuffTail  Carder bee  Garden bee  Honeybee  Red tail
# Thistle               10           8           8        12        18
# Vipers Bugloss         1          27           3        13         9
# Golden Rain           37           6          19        16         1
# Yellow Alfalfa         5          32           6         9         2
# Blackberry            12          23           4        10         4

# %%
df.as_matrix()
# Out:
# array([[10,  8,  8, 12, 18],
#        [ 1, 27,  3, 13,  9],
#        [37,  6, 19, 16,  1],
#        [ 5, 32,  6,  9,  2],
#        [12, 23,  4, 10,  4]])

# %%
print(df.loc['Blackberry'])
# Out:
# BuffTail      12
# Carder bee    23
# Garden bee     4
# Honeybee      10
# Red tail       4
# Name: Blackberry, dtype: int64

# %%
print(df.loc['Golden Rain'])
# Out:
# BuffTail      37
# Carder bee     6
# Garden bee    19
# Honeybee      16
# Red tail       1
# Name: Golden Rain, dtype: int64

# %%
print(df.loc['Yellow Alfalfa'])
# Out:
# BuffTail       5
# Carder bee    32
# Garden bee     6
# Honeybee       9
# Red tail       2
# Name: Yellow Alfalfa, dtype: int64

# %%
df['Red tail']
# Out:
# Thistle           18
# Vipers Bugloss     9
# Golden Rain        1
# Yellow Alfalfa     2
# Blackberry         4
# Name: Red tail, dtype: int64

# %%
a=(df.sort_values(by=['BuffTail'],ascending=False))
a
# Out:
#                 BuffTail  Carder bee  Garden bee  Honeybee  Red tail
# Golden Rain           37           6          19        16         1
# Blackberry            12          23           4        10         4
# Thistle               10           8           8        12        18
# Yellow Alfalfa         5          32           6         9         2
# Vipers Bugloss         1          27           3        13         9
